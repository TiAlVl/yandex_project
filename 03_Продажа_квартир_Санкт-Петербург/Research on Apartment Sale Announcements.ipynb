# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Стиль-заголовков" data-toc-modified-id="Стиль-заголовков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Стиль заголовков</a></span></li><li><span><a href="#Пропуски-значений" data-toc-modified-id="Пропуски-значений-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Пропуски значений</a></span><ul class="toc-item"><li><span><a href="#Определите-и-изучите-пропущенные-значения:" data-toc-modified-id="Определите-и-изучите-пропущенные-значения:-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Определите и изучите пропущенные значения:</a></span></li></ul></li><li><span><a href="#Приведите-данные-к-нужным-типам" data-toc-modified-id="Приведите-данные-к-нужным-типам-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Приведите данные к нужным типам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Считаем-и-добавляем-в-таблицу:" data-toc-modified-id="Считаем-и-добавляем-в-таблицу:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Считаем и добавляем в таблицу:</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра." data-toc-modified-id="Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.</a></span></li><li><span><a href="#Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили." data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.</a></span></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.</a></span></li><li><span><a href="#Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-(locality_name).-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-(locality_name).-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.</a></span></li><li><span><a href="#Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всей-базе?" data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всей-базе?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><span><a href="#Факторы-влияющие-на-цену-квартир." data-toc-modified-id="Факторы-влияющие-на-цену-квартир.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Факторы влияющие на цену квартир.</a></span></li><li><span><a href="#Параметры-квартир,-лучше-всего-продающихся-в-центе-Санкт-Петербурга:" data-toc-modified-id="Параметры-квартир,-лучше-всего-продающихся-в-центе-Санкт-Петербурга:-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Параметры квартир, лучше всего продающихся в центе Санкт-Петербурга:</a></span></li><li><span><a href="#Параметры-квартир,-лучше-всего-продающихся-по-Санкт-Петербугру:" data-toc-modified-id="Параметры-квартир,-лучше-всего-продающихся-по-Санкт-Петербугру:-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Параметры квартир, лучше всего продающихся по Санкт-Петербугру:</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pymystem3 import Mystem
m = Mystem()

# %%
# добавил модуль про варнинги
import warnings

# %%
# Игнорируем предупреждения
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('/datasets/real_estate_data.csv')

# %%
data.head()
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...

# %% [markdown]
# Используется разделитель данных "\t"

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t', decimal='.')

# %%
data.head(10) # первые 10 строк для наглядности
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
data.tail(10) # и последние 10 строк
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23689            13   3550000.0       35.30  2018-02-28T00:00:00      1
# 23690             3   5500000.0       52.00  2018-07-19T00:00:00      2
# 23691            11   9470000.0       72.90  2016-10-13T00:00:00      2
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23693             9   4600000.0       62.40  2016-08-05T00:00:00      3
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23689            2.86          15.0         16.3      4          NaN  ...
# ...

# %% [markdown]
# В данных содержатся много незаполненных ячеек со значением NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# **По общей информации можно сделать вывод**,
#
# Имеется 22 столбца, два булевых, 14 флотов , 3 инт и 3 object
#
# Количество значений в столбцах различается, что говорит о наличии пропусков данных в большинстве столбцов.
#
# Столбец cityCenters_nearest лучше переименовать согласно "змеиного" регистра в city_center_nearest
#
# **Согласно документации данные в столбцах:**
#
# *	airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# *	balcony — число балконов
# *	ceiling_height — высота потолков (м)
# *	cityCenters_nearest — расстояние до центра города (м)
# *	days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# *	first_day_exposition — дата публикации
# *	floor — этаж
# *	floors_total — всего этажей в доме
# *	is_apartment — апартаменты (булев тип)
# *	kitchen_area — площадь кухни в квадратных метрах (м²)
# *	last_price — цена на момент снятия с публикации
# *	living_area — жилая площадь в квадратных метрах (м²)
# *	locality_name — название населённого пункта
# *	open_plan — свободная планировка (булев тип)
# *	parks_around3000 — число парков в радиусе 3 км
# *	parks_nearest — расстояние до ближайшего парка (м)
# *	ponds_around3000 — число водоёмов в радиусе 3 км
# *	ponds_nearest — расстояние до ближайшего водоёма (м)
# *	rooms — число комнат
# *	studio — квартира-студия (булев тип)
# *	total_area — площадь квартиры в квадратных метрах (м²)
# *	total_images — число фотографий квартиры в объявлении

# %%
len(data) #всего строк в датасете
# Out:
# 23699

# %% [markdown]
# ### Вывод
#
# В каждой строке таблицы — данные об объекте недвижимости. Часть колонок описывает сам объект недвижимости: Площадь частей помещения и количество комнат, этаж и этажность, тип помещения, название населенного пункта, в котором он находится. Остальные данные рассказывают о инфраструктуре рядом с объектом недвижимости и о самом объявлении: наличие водоемов, расстояние до значимых транспортных узлов, о количестве фотографий в объявлении.
#
# Предварительно можно утверждать, что, данных достаточно для проверки гипотез. Но встречаются пропуски в данных, а в названиях колонок — расхождения с хорошим стилем.
#
# Чтобы двигаться дальше, нужно устранить проблемы в данных.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Исправим стиль в заголовках столбцов, исключите пропуски, проверим данные на дубликаты.

# %% [markdown]
# ### Стиль заголовков

# %%
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %%
data = data.rename(
    columns={
        'cityCenters_nearest': 'city_centers_nearest',
        'parks_around3000': 'parks_around_3000',
        'ponds_around3000': 'ponds_around_3000'
    })

# %%
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# ### Пропуски значений

# %% [markdown]
# ####	Определите и изучите пропущенные значения:
#
# - Для некоторых пропущенных значений можно предположить логичную замену. Например, если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0. Для других типов данных нет подходящего значения на замену. В этом случае правильно оставить эти значения пустыми. Отсутствие значения — тоже важный сигнал, который не нужно прятать.
#
# - Заполним пропуски, где это уместно с пояснением причин заполнения
#
# - Укажите причины, которые могли привести к пропускам в данных.

# %%
data.duplicated().sum()
# В датафрейме пока нет дубликатов
# Out:
# 0

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Пропуски в датасете в наличии в большинстве столбцов
#
# - ceiling_height - пропуски в выстое потолков, сходу мыслей нет, почему не указано.
# - floors_total - этажность дома не указана, можно посмотреть по другим объявлениям максимальный этаж в этом доме.
# - living_area - пропуски в жилой площади, могут быть связаны с тем, что тип помещения нежилой
# - is_apartment - апартаменты. столбец с булевым типом. По факту либо апартаменты, либо нет.
# - kitchen_area - пропуски в площади кухни. может связано с тем, что кухни просто нет в помещении.
# - balcony - пропуски в балконах. скорее всего балконы отсутствуют, думаю можно заменить пропуски на нули.
# - locality_name - пропуски в названии населенного пункта, забыли указать?
# - airports_nearest - пропуски в столбце с расстоянием до ближайшего аэропорта. Возможно он отсутсвует в этом нас. пункте
# - city_centers_nearest - пропуски в столбце с расстоянием до центра города.
# - parks_around_3000 - пропуски данных о количестве парков в радиусе 3х км, тут надо смотреть вместе с данными о расстоянии до ближайшего парка, если есть такое расстояние, то вместо пропуска можно указать 1
# - parks_nearest - пропуски данных о расстоянии до ближайшего парка - надо смотерть вместе с parks_around_3000
# - ponds_around_3000 - нет данных о водоемах в радиусе 3х км от объекта
# - ponds_nearest - нет данных о расстоянии до ближайшего водоема
# - days_exposition - есть пропуски в данных о днях размещения объявления

# %% [markdown]
# Что точно прямо сейчас можно сделать, это заполнить данные по балконам нулями

# %%
data['balcony'].unique()  # проверим уникальные значения в столбце
# Out:
# array([nan,  2.,  0.,  1.,  5.,  4.,  3.])

# %%
data['balcony'] = data['balcony'].fillna(0)

# %%
data['balcony'].unique() # пропуски заменены на 0. Думаю, если значение не указано - значит балкона нет.
# Out:
# array([0., 2., 1., 5., 4., 3.])

# %%
data['balcony'].hist() # наглядно количество балконов в квартирах
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видно, что 3 и более балконов - весьма редкие варианты квартир.

# %%
# пропуски и аномальные значения в высоте потолков
data['ceiling_height'].sort_values().unique()
# Out:
# array([  1.  ,   1.2 ,   1.75,   2.  ,   2.2 ,   2.25,   2.3 ,   2.34,
#          2.4 ,   2.45,   2.46,   2.47,   2.48,   2.49,   2.5 ,   2.51,
#          2.52,   2.53,   2.54,   2.55,   2.56,   2.57,   2.58,   2.59,
#          2.6 ,   2.61,   2.62,   2.63,   2.64,   2.65,   2.66,   2.67,
#          2.68,   2.69,   2.7 ,   2.71,   2.72,   2.73,   2.74,   2.75,
#          2.76,   2.77,   2.78,   2.79,   2.8 ,   2.81,   2.82,   2.83,
#          2.84,   2.85,   2.86,   2.87,   2.88,   2.89,   2.9 ,   2.91,
#          2.92,   2.93,   2.94,   2.95,   2.96,   2.97,   2.98,   2.99,
#          3.  ,   3.01,   3.02,   3.03,   3.04,   3.05,   3.06,   3.07,
#          3.08,   3.09,   3.1 ,   3.11,   3.12,   3.13,   3.14,   3.15,
#          3.16,   3.17,   3.18,   3.2 ,   3.21,   3.22,   3.23,   3.24,
#          3.25,   3.26,   3.27,   3.28,   3.29,   3.3 ,   3.31,   3.32,
#          3.33,   3.34,   3.35,   3.36,   3.37,   3.38,   3.39,   3.4 ,
# ...

# %%
# наглядно квартиры с неправдоподобными высотами потолков. Норма выстоы потолка 2,5 метра.
data.query('ceiling_height > 10 or 0 < ceiling_height < 2.4').plot(kind='hist', y='ceiling_height') 
data.query('ceiling_height > 10 or 0 < ceiling_height < 2.4')['ceiling_height'].count()/len(data)*100 
# их доля в датафрейме меньше пятой части процента
# Out:
# 0.19410101692054516

# %%
len(data.loc[data['ceiling_height'].isna()]['ceiling_height'])/len(data)*100 
# доля NaN по высотам потолков в датафрейме составляет почти 39 процентов
# Out:
# 38.799105447487236

# %%
ceiling_height_median = data['ceiling_height'].median()
ceiling_height_median # медиана высоты потолка
# Out:
# 2.65

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(ceiling_height_median) 
# заменю пропуски (наны) в столбце с высотой на медиану по столбцу

# %%
ceiling_height_normal = data.loc[(data['ceiling_height'] <= 10) & (data['ceiling_height'] > 2.4), 'ceiling_height'].sort_values().unique()
ceiling_height_normal # список высот потолков от 2,4 до 10 метров
# Out:
# array([2.45, 2.46, 2.47, 2.48, 2.49, 2.5 , 2.51, 2.52, 2.53, 2.54, 2.55,
#        2.56, 2.57, 2.58, 2.59, 2.6 , 2.61, 2.62, 2.63, 2.64, 2.65, 2.66,
#        2.67, 2.68, 2.69, 2.7 , 2.71, 2.72, 2.73, 2.74, 2.75, 2.76, 2.77,
#        2.78, 2.79, 2.8 , 2.81, 2.82, 2.83, 2.84, 2.85, 2.86, 2.87, 2.88,
#        2.89, 2.9 , 2.91, 2.92, 2.93, 2.94, 2.95, 2.96, 2.97, 2.98, 2.99,
#        3.  , 3.01, 3.02, 3.03, 3.04, 3.05, 3.06, 3.07, 3.08, 3.09, 3.1 ,
#        3.11, 3.12, 3.13, 3.14, 3.15, 3.16, 3.17, 3.18, 3.2 , 3.21, 3.22,
#        3.23, 3.24, 3.25, 3.26, 3.27, 3.28, 3.29, 3.3 , 3.31, 3.32, 3.33,
#        3.34, 3.35, 3.36, 3.37, 3.38, 3.39, 3.4 , 3.42, 3.43, 3.44, 3.45,
#        3.46, 3.47, 3.48, 3.49, 3.5 , 3.51, 3.52, 3.53, 3.54, 3.55, 3.56,
#        3.57, 3.58, 3.59, 3.6 , 3.62, 3.63, 3.65, 3.66, 3.67, 3.68, 3.69,
#        3.7 , 3.75, 3.76, 3.78, 3.8 , 3.82, 3.83, 3.84, 3.85, 3.86, 3.87,
#        3.88, 3.9 , 3.93, 3.95, 3.98, 4.  , 4.06, 4.1 , 4.14, 4.15, 4.19,
# ...

# %%
data['ceiling_height'] = data['ceiling_height'].where(data['ceiling_height'].isin(ceiling_height_normal), ceiling_height_median)
# в столбце с высотами заменил аномальные высоты потолков ниже 2,4 м и выше 10 м на медианное значение.

# %%
data['ceiling_height'].sort_values().unique()
# Out:
# array([2.45, 2.46, 2.47, 2.48, 2.49, 2.5 , 2.51, 2.52, 2.53, 2.54, 2.55,
#        2.56, 2.57, 2.58, 2.59, 2.6 , 2.61, 2.62, 2.63, 2.64, 2.65, 2.66,
#        2.67, 2.68, 2.69, 2.7 , 2.71, 2.72, 2.73, 2.74, 2.75, 2.76, 2.77,
#        2.78, 2.79, 2.8 , 2.81, 2.82, 2.83, 2.84, 2.85, 2.86, 2.87, 2.88,
#        2.89, 2.9 , 2.91, 2.92, 2.93, 2.94, 2.95, 2.96, 2.97, 2.98, 2.99,
#        3.  , 3.01, 3.02, 3.03, 3.04, 3.05, 3.06, 3.07, 3.08, 3.09, 3.1 ,
#        3.11, 3.12, 3.13, 3.14, 3.15, 3.16, 3.17, 3.18, 3.2 , 3.21, 3.22,
#        3.23, 3.24, 3.25, 3.26, 3.27, 3.28, 3.29, 3.3 , 3.31, 3.32, 3.33,
#        3.34, 3.35, 3.36, 3.37, 3.38, 3.39, 3.4 , 3.42, 3.43, 3.44, 3.45,
#        3.46, 3.47, 3.48, 3.49, 3.5 , 3.51, 3.52, 3.53, 3.54, 3.55, 3.56,
#        3.57, 3.58, 3.59, 3.6 , 3.62, 3.63, 3.65, 3.66, 3.67, 3.68, 3.69,
#        3.7 , 3.75, 3.76, 3.78, 3.8 , 3.82, 3.83, 3.84, 3.85, 3.86, 3.87,
#        3.88, 3.9 , 3.93, 3.95, 3.98, 4.  , 4.06, 4.1 , 4.14, 4.15, 4.19,
# ...

# %%
# доля квартир с аномальными высотами в датафрейме 
#plt.ylim(0,10)
data.query('ceiling_height <= 10 or ceiling_height > 2.4').boxplot(column='ceiling_height')
data['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.698463
# std          0.230996
# min          2.450000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          8.300000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Пропуски в этажности дома

# %%
data['floors_total'].isna().sum()
#
# Out:
# 86

# %%
(data
     .query('floors_total.isna()')
     .isna().sum()
)
# Out:
# total_images             0
# last_price               0
# total_area               0
# first_day_exposition     0
# rooms                    0
# ceiling_height           0
# floors_total            86
# living_area             33
# floor                    0
# is_apartment            86
# studio                   0
# open_plan                0
# kitchen_area            47
# balcony                  0
# locality_name            1
# airports_nearest        10
# city_centers_nearest    10
# parks_around_3000       10
# parks_nearest           52
# ponds_around_3000       10
# ponds_nearest           37
# days_exposition          9
# dtype: int64

# %%
# 86 пропуска в этажности дома. плюс есть пропуски по другим столбцам, думаю можно удалить эти данные
data.dropna(subset=['floors_total'], inplace = True)

# %%
# Пропуски в названии нас пункта
(data
     .query('locality_name.isna()')
     .isna().sum()
)
# Out:
# total_images             0
# last_price               0
# total_area               0
# first_day_exposition     0
# rooms                    0
# ceiling_height           0
# floors_total             0
# living_area              5
# floor                    0
# is_apartment            33
# studio                   0
# open_plan                0
# kitchen_area             9
# balcony                  0
# locality_name           48
# airports_nearest         8
# city_centers_nearest     8
# parks_around_3000        8
# parks_nearest           33
# ponds_around_3000        8
# ponds_nearest           23
# days_exposition          1
# dtype: int64

# %% [markdown]
# Всего 48 пропусков в датасете с названием нас. пункта.
# Врядли Можно восстановить эту часть по данным об удаленности от центра, поэтому удаляю.

# %%
data.dropna(subset=['locality_name'], inplace = True)

# %%
# Дубли в названии нас пункта
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %%
# сделаю названия нас пунктов в отдельный столбец
data['locality_name_short'] = data['locality_name'].replace(['поселок ', 'посёлок ', 'деревня ', ' городского ', ' типа ', 'городской ', 'село ', ' коттеджный ', 'имени ', 'городского', 'садовое ','товарищество ', 'станции ', 'садоводческое некоммерческое ','при железнодорожной ','коттеджный '], '', regex=True)

# %%
data['locality_name_short'].unique() #Добавил столбец с коротким названием нас пункта
# Out:
# array(['Санкт-Петербург', 'Шушары', 'Янино-1', 'Парголово', 'Мурино',
#        'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин', 'Кудрово',
#        'Коммунар', 'Колпино', 'Красный Бор', 'Гатчина', 'Фёдоровское',
#        'Выборг', 'Кронштадт', 'Кировск', 'Новое Девяткино',
#        'Металлострой', 'Лебяжье', 'Сиверский', 'Молодцово',
#        'Кузьмоловский', 'Новая Ропша', 'Павловск', 'Пикколово',
#        'Всеволожск', 'Волхов', 'Кингисепп', 'Приозерск', 'Сестрорецк',
#        'Куттузи', 'Аннино', 'Ефимовский', 'Плодовое', 'Заклинье',
#        'Торковичи', 'Первомайское', 'Красное Село', 'Понтонный',
#        'Сясьстрой', 'Старая', 'Лесколово', 'Новый Свет', 'Сланцы',
#        'Путилово', 'Ивангород', 'Шлиссельбург', 'Никольское',
#        'Зеленогорск', 'Сосновый Бор', 'Оржицы', 'Кальтино', 'Романовка',
#        'Бугры', 'Рощино', 'Кириши', 'Луга', 'Волосово', 'Отрадное',
#        'Павлово', 'Оредеж', 'Копорье', 'Молодёжное', 'Тихвин', 'Победа',
# ...

# %%
len(data.groupby('locality_name'))
# Out:
# 364

# %%
len(data.groupby('locality_name_short'))
# Приведение к короткому названию позволило объединить дубликаты в названиях нас пунктов
# Out:
# 305

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23565.000000  2.356500e+04  23565.000000  23565.000000    23565.000000
# mean       9.878421  6.540058e+06     60.322824      2.070656        2.698488
# std        5.681156  1.091093e+07     35.657060      1.078591        0.231326
# min        0.000000  1.219000e+04     12.000000      0.000000        2.450000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.646000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.790000e+06     69.700000      3.000000        2.700000
# max       50.000000  7.630000e+08    900.000000     19.000000        8.300000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23565.000000  21700.000000  23565.000000  21343.000000  23565.000000
# mean      10.675875     34.454822      5.878124     10.560994      0.593677
# ...

# %% [markdown]
# С метододм describe() не очень нагляден столбец last_price, чуть поправить

# %%
data.describe().apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#       total_images    last_price total_area     rooms ceiling_height  \
# count     23565.00      23565.00   23565.00  23565.00       23565.00
# mean          9.88    6540058.26      60.32      2.07           2.70
# std           5.68   10910934.72      35.66      1.08           0.23
# min           0.00      12190.00      12.00      0.00           2.45
# 25%           6.00    3400000.00      40.00      1.00           2.60
# 50%           9.00    4646000.00      52.00      2.00           2.65
# 75%          14.00    6790000.00      69.70      3.00           2.70
# max          50.00  763000000.00     900.00     19.00           8.30
#
#       floors_total living_area     floor kitchen_area   balcony  \
# count     23565.00    21700.00  23565.00     21343.00  23565.00
# mean         10.68       34.45      5.88        10.56      0.59
# std           6.59       22.05      4.87         5.90      0.96
# min           1.00        2.00      1.00         1.30      0.00
# ...

# %% [markdown]
# Теперь видно, что есть объявления с неправдоподобными данными, такмим как нулевое количество комнат, либо количество комнат не указано, жилая площадь в два квадратных метра, кухня в 1,3 кв. метров.
#
# - Нулевое количество комнат - вероятно апартаменты, либо студии
# - жилая площадь в два квадратных метра - ненормальные данные, норма на человека 9 кв .м в квартире
# - кухня в 1,3 метра квадратных - неправдоподобно

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)
# Пропуски в апартаментах заменил на False.

# %%
#количество объявлений с пропусками либо с количестовм комнат, равным нулю
len(data.query('rooms.isna() or rooms == 0'))
# Out:
# 194

# %%
#Заменю 0 на 1 в количестве комнат.
data['rooms'] = data['rooms'].replace(0, 1)

# %%
len(data.query('rooms.isna() or rooms == 0'))
# Out:
# 0

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1865
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2222
# balcony                     0
# locality_name               0
# airports_nearest         5524
# city_centers_nearest     5501
# parks_around_3000        5500
# parks_nearest           15535
# ponds_around_3000        5500
# ponds_nearest           14529
# days_exposition          3171
# locality_name_short         0
# dtype: int64

# %% [markdown]
# Остались пропуски в жилой данных по жилой площади, площади кухни.
#
# Такие пропуски данных, как растояние до аэропорта, количество парков и водоемов, и расстояние до них - эти даные неоткуда восстановить, оставлю пропусками.

# %%
(data
     .query('living_area.isna()')[['floors_total','kitchen_area','living_area']]
)
# сплошные пропуски в жилой площади (наны) в количестве 1865 штук
# Out:
#        floors_total  kitchen_area  living_area
# 3              14.0           NaN          NaN
# 7              24.0          18.9          NaN
# 30              9.0           NaN          NaN
# 37              5.0           NaN          NaN
# 44             22.0           NaN          NaN
# ...             ...           ...          ...
# 23642          12.0           NaN          NaN
# 23663          10.0           NaN          NaN
# 23670           9.0           NaN          NaN
# 23679           9.0           NaN          NaN
# 23697          17.0          23.3          NaN
#
# [1865 rows x 3 columns]

# %%
(data
     .query('kitchen_area.isna()')[['floors_total','kitchen_area','living_area']]
)
# сплошные пропуски в жилой площади (наны) в количестве 2222 штук
# Out:
#        floors_total  kitchen_area  living_area
# 3              14.0           NaN          NaN
# 30              9.0           NaN          NaN
# 37              5.0           NaN          NaN
# 44             22.0           NaN          NaN
# 59             13.0           NaN          NaN
# ...             ...           ...          ...
# 23655          18.0           NaN         19.6
# 23663          10.0           NaN          NaN
# 23670           9.0           NaN          NaN
# 23679           9.0           NaN          NaN
# 23696           3.0           NaN         29.7
#
# [2222 rows x 3 columns]

# %% [markdown]
#  Посчитаю медиану для площадей кухни и жилой площажи с учетом количества комнат

# %%
# сводная таблица по комнатам и площадям, значения минимума, максимума и медиана
data.pivot_table(index='rooms', values=['kitchen_area','living_area','total_area'], aggfunc=['median','min','max'])
# Out:
#             median                                 min                         \
#       kitchen_area living_area total_area kitchen_area living_area total_area
# rooms
# 1             9.00      17.600      36.30          1.3         2.0       12.0
# 2             8.70      30.500      53.00          2.0         2.0       20.0
# 3             9.50      45.000      72.80          4.0         3.0       40.1
# 4            11.00      63.650      99.30          4.8         5.4       42.0
# 5            15.10      91.785     146.00          5.0        23.6       40.0
# 6            19.75     124.400     186.15          5.9        68.0       87.0
# 7            20.00     145.000     214.00          5.0        57.4      100.6
# 8            25.00     161.000     235.70          5.0       107.0      150.0
# 9            14.30     179.200     300.95         11.7       157.0      235.0
# 10           19.80     161.400     272.60         18.8       145.9      216.1
# ...

# %% [markdown]
#  Из таблицы видно, что есть объявления с площадью кухни менее 5 кв.м и жилой площадью менее 9 кв. м.

# %%
# Жилая площадь с площадью менее 9 кв. метров 
bad_living_area = data.query('living_area < 9')[['living_area','kitchen_area','rooms','locality_name']]
bad_living_area
# Out:
#        living_area  kitchen_area  rooms    locality_name
# 114            8.3           6.3      1  Санкт-Петербург
# 2309           8.4          41.0      2   посёлок Шушары
# 3242           3.0          11.0      1  Санкт-Петербург
# 13915          2.0           9.0      2  Санкт-Петербург
# 16431          6.0          17.0      1  Санкт-Петербург
# 17248          8.9          16.1      1  Санкт-Петербург
# 17582          5.0           NaN      1  Санкт-Петербург
# 19251          6.5          18.0      1  Санкт-Петербург
# 20994          8.0          31.0      2  Санкт-Петербург
# 21505          8.5          16.1      1  Санкт-Петербург
# 21758          2.0           NaN      1   посёлок Мурино
# 21943          5.4           9.8      4  Санкт-Петербург
# 23208          8.0          22.0      1  Санкт-Петербург
# 23574          3.0          16.0      3  Санкт-Петербург

# %%
# В количестве:
len(bad_living_area)
# Out:
# 14

# %%
# удаляем 'плохие' жилые площади
data = data.drop(bad_living_area.index)

# %%
# Проверяем
data.query('living_area < 9')[['living_area','kitchen_area','rooms','locality_name']].count()
# Out:
# living_area      0
# kitchen_area     0
# rooms            0
# locality_name    0
# dtype: int64

# %%
# Кухни с площадью менее 5 кв. метров 
bad_kitchen_area = data.query('kitchen_area < 5')[['living_area','kitchen_area','rooms','locality_name']]
bad_kitchen_area
# Out:
#        living_area  kitchen_area  rooms     locality_name
# 76            38.4           4.9      3           Кировск
# 298           30.0           4.5      2           Гатчина
# 422           38.5           4.5      3            Кириши
# 906           18.0           2.0      1   Санкт-Петербург
# 1327          29.2           4.9      2           Гатчина
# ...            ...           ...    ...               ...
# 22839          NaN           4.0      1   Санкт-Петербург
# 22849         19.0           4.0      1    посёлок Шушары
# 23110         20.0           4.0      2  посёлок Стрельна
# 23498         33.0           3.5      2            Высоцк
# 23678         26.1           4.9      2            Пушкин
#
# [104 rows x 4 columns]

# %%
# # Кухни с площадью менее 5 кв. метров в количестве 104 записей. Удалю их
data = data.drop(bad_kitchen_area.index)

# %%
data.query('kitchen_area < 5')[['living_area','kitchen_area','rooms','locality_name']].count()
# Out:
# living_area      0
# kitchen_area     0
# rooms            0
# locality_name    0
# dtype: int64

# %%
# После чистки датасета от "плохих" площадей кухни и жилой площади смотрим медиану с учетом количества комнат в объекте недвижимости
data.pivot_table(index='rooms', values=['kitchen_area','living_area','total_area'], aggfunc=['median','min','max','count'])
# Out:
#             median                                 min                         \
#       kitchen_area living_area total_area kitchen_area living_area total_area
# rooms
# 1             9.10      17.600      36.40          5.0         9.0       12.0
# 2             8.80      30.500      53.00          5.0         9.0       20.0
# 3             9.50      45.000      72.90          5.0        12.5       40.1
# 4            11.10      63.800      99.50          5.0        21.5       42.0
# 5            15.10      91.785     146.00          5.0        23.6       40.0
# 6            19.75     124.400     186.15          5.9        68.0       87.0
# 7            20.00     145.000     214.00          5.0        57.4      100.6
# 8            25.00     161.000     235.70          5.0       107.0      150.0
# 9            14.30     179.200     300.95         11.7       157.0      235.0
# 10           19.80     161.400     272.60         18.8       145.9      216.1
# ...

# %%
# Вместо пропусков в площади кухни и в жилой площади укажем медиану с учетом числа комнат
data['living_area_median'] = data['living_area'].fillna(data.groupby('rooms')['living_area'].transform("median"))

# %%
data['kitchen_area_median'] = data['kitchen_area'].fillna(data.groupby('rooms')['kitchen_area'].transform("median"))

# %%
data.pivot_table(index='rooms', values=['living_area_median', 'kitchen_area_median'], aggfunc=['median','last','first','count'])
# Out:
#                    median                                   last  \
#       kitchen_area_median living_area_median kitchen_area_median
# rooms
# 1                    9.10             17.600                 9.0
# 2                    8.80             30.500                23.3
# 3                    9.50             45.000                 8.5
# 4                   11.10             63.800                15.6
# 5                   15.10             91.785                10.0
# 6                   19.75            124.400                20.0
# 7                   20.00            145.000                12.4
# 8                   25.00            161.000                29.4
# 9                   14.30            179.200                11.7
# 10                  19.80            161.400                30.0
# 11                  12.60            133.900                11.9
# 12                 112.00            409.700               112.0
# ...

# %%
# пропуски на медианное значение с учетом количества комнат
data['kitchen_area'] = data['kitchen_area'].fillna(data['kitchen_area_median'])

# %%
data['kitchen_area'].isna().sum()
# Out:
# 0

# %%
# пропуски на медианное значение с учетом количества комнат
data['living_area'] = data['living_area'].fillna(data['living_area_median'])

# %%
data['living_area'].isna().sum()
# Out:
# 0

# %%
data[~data['kitchen_area'].isna()].boxplot(column='kitchen_area')
data['kitchen_area'].describe()
# Out:
# count    23447.000000
# mean        10.474752
# std          5.633358
# min          5.000000
# 25%          7.400000
# 50%          9.100000
# 75%         11.500000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
# пропуски в Санкт-Петербурге в столбце с расстоянием до аэропорта
data.query('locality_name == "Санкт-Петербург" and airports_nearest.isna()')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 81                9   10949000.0       68.00  2018-12-27T00:00:00      1
# 593              20    4200000.0       38.30  2019-04-16T00:00:00      1
# 604              11    9899000.0      101.00  2018-12-12T00:00:00      3
# 733              18   18700000.0      109.70  2018-02-03T00:00:00      3
# 742               7   37000000.0      161.00  2016-05-22T00:00:00      3
# ...             ...          ...         ...                  ...    ...
# 21955            19  130000000.0      431.00  2017-10-02T00:00:00      7
# 22554             5    3415000.0       31.65  2019-04-16T00:00:00      1
# 22628             8    8600000.0       74.90  2019-03-14T00:00:00      3
# 22790             8    5600000.0       47.00  2017-09-27T00:00:00      1
# 23124             0    3500000.0       41.30  2018-01-11T00:00:00      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
#84 пропуска в столбце расстояния до аэропорта, заменю медианным значением по столбцу
airports_nearest_median = data['airports_nearest'].median()
airports_nearest_median
# Out:
# 26763.0

# %%
data['airports_nearest'] = data.query('locality_name == "Санкт-Петербург"')['airports_nearest'].fillna(airports_nearest_median)
# заменю пропуски (наны) в столбце с  на медиану по столбцу

# %%
# в отсортированных уникальных значениях наны пропали
data.query('locality_name == "Санкт-Петербург"')['airports_nearest'].sort_values().unique()
# Out:
# array([    0.,  6450.,  6914., ..., 54535., 54723., 54784.])

# %%
# пропуски в Санкт-Петербурге в столбце с расстоянием до центар
data.query('locality_name == "Санкт-Петербург" and city_centers_nearest.isna()')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 81                9   10949000.0       68.00  2018-12-27T00:00:00      1
# 593              20    4200000.0       38.30  2019-04-16T00:00:00      1
# 604              11    9899000.0      101.00  2018-12-12T00:00:00      3
# 742               7   37000000.0      161.00  2016-05-22T00:00:00      3
# 795              19    7100000.0       59.60  2019-02-13T00:00:00      2
# 1336             12   18500000.0       66.00  2017-06-08T00:00:00      1
# 1872             13    3100000.0       32.00  2019-03-15T00:00:00      1
# 1895             12    9500000.0      130.00  2019-03-27T00:00:00      5
# 2364             17    4300000.0       32.60  2019-04-28T00:00:00      1
# 2707             14    5650000.0       51.00  2019-02-26T00:00:00      2
# 2882              6   28099500.0      174.00  2018-12-19T00:00:00      3
# 3200              9   10912400.0       68.00  2018-12-19T00:00:00      1
# ...

# %%
city_centers_nearest_median = data['city_centers_nearest'].median()
city_centers_nearest_median
# Out:
# 13094.5

# %%
data['city_centers_nearest'] = data.query('locality_name == "Санкт-Петербург"')['city_centers_nearest'].fillna(city_centers_nearest_median)
# заменю пропуски (наны) в столбце с  на медиану по столбцу

# %%
# в отсортированных уникальных значениях наны пропали
data.query('locality_name == "Санкт-Петербург"')['city_centers_nearest'].sort_values().unique()
# Out:
# array([  181.,   208.,   215., ..., 29263., 29343., 29493.])

# %%
data.query('days_exposition.isna()')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 7                 5   7915000.0       71.60  2019-04-18T00:00:00      2
# 44               13   5350000.0       40.00  2018-11-18T00:00:00      1
# 45               17   5200000.0       50.60  2018-12-02T00:00:00      2
# 46               17   6600000.0       52.10  2019-01-31T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23684            20  21400000.0      145.00  2018-11-02T00:00:00      4
# 23685            15   2490000.0       31.00  2019-01-24T00:00:00      1
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
# Количество объявлений без фотографий
data.query('total_images == 0')['total_images'].count()
# Out:
# 1045

# %%
# нет значений дней размещения объявления - вероятно  объявление было создано, но не публиковалось, заменю на 0
data['days_exposition'].isna().sum()
# Out:
# 3155

# %%
data['days_exposition'] = data['days_exposition'].fillna(0)

# %%
# замена прошла успешно
data['days_exposition'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Приведите данные к нужным типам

# %% [markdown]
# типы данных в датасете

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23447 entries, 0 to 23698
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23447 non-null  int64
#  1   last_price            23447 non-null  float64
#  2   total_area            23447 non-null  float64
#  3   first_day_exposition  23447 non-null  object
#  4   rooms                 23447 non-null  int64
#  5   ceiling_height        23447 non-null  float64
#  6   floors_total          23447 non-null  float64
#  7   living_area           23447 non-null  float64
#  8   floor                 23447 non-null  int64
#  9   is_apartment          23447 non-null  bool
#  10  studio                23447 non-null  bool
#  11  open_plan             23447 non-null  bool
#  12  kitchen_area          23447 non-null  float64
#  13  balcony               23447 non-null  float64
#  14  locality_name         23447 non-null  object
# ...

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8         False  ...
# 1            2.65          11.0         18.6      1         False  ...
# 2            2.65           5.0         34.3      4         False  ...
# 3            2.65          14.0         45.0      9         False  ...
# 4            3.03          14.0         32.0     13         False  ...
#
#    airports_nearest  city_centers_nearest  parks_around_3000  parks_nearest  \
# ...

# %%
data['floors_total'] = data['floors_total'].astype('int')
# Количество этажей - целое число
data['last_price'] = data['last_price'].astype('int') 
# Цена на квартиру такая, что копейки не интересны совсем
data['balcony'] = data['balcony'].astype('int') 
# Количество балконов - целое число
data['days_exposition'] = data['days_exposition'].astype('int') 
# Количество дней публикации
data['rooms'] = data['rooms'].astype('int') 
# Количество комнат

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23447 entries, 0 to 23698
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23447 non-null  int64
#  1   last_price            23447 non-null  int64
#  2   total_area            23447 non-null  float64
#  3   first_day_exposition  23447 non-null  object
#  4   rooms                 23447 non-null  int64
#  5   ceiling_height        23447 non-null  float64
#  6   floors_total          23447 non-null  int64
#  7   living_area           23447 non-null  float64
#  8   floor                 23447 non-null  int64
#  9   is_apartment          23447 non-null  bool
#  10  studio                23447 non-null  bool
#  11  open_plan             23447 non-null  bool
#  12  kitchen_area          23447 non-null  float64
#  13  balcony               23447 non-null  int64
#  14  locality_name         23447 non-null  object
# ...

# %%
data.duplicated().sum()
#Дублей не наблюдается
# Out:
# 0

# %% [markdown]
# ### Вывод
# в данной части проекта было реализовано:
# - убраны пропуски в большей части данных, а именно пропуски по балконам были замененны нулями, пропуски в столбцах расстояния до аэропорта и до центра, заменены медианными значениями
# - пропуски и аномальные высоты потолков  заменены медианным значением
# - удалены из данных к анализу объявления без данных об этажности дома, а также объявления без указания населенного пункта, объявления с неправдоподобными площадьми кухни (менее 5 кв.м.) и жилых комнат (менее 9 к.м.)
# - Названия населенных пунктов выведены в отдельный столбец в сокращенном виде, что сократило дубликаты по нас пунктам
# - убраны пропуски в жилой площади и в площади кухни. Эти пропуски заменены медианным значением, рассчитаным с учетом числа комнат
# - Изменены типы данных у столбцов: rooms, days_exposition, balcony, last_price, floors_total
# - Произведенам проверка на наличие дубликатов, которых не оказалось

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Считаем и добавляем в таблицу:
# - цену квадратного метра;
# - день недели, месяц и год публикации объявления;
# - этаж квартиры; варианты — первый, последний, другой;
# - соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %% [markdown]
# Считаем цену квадратного метра

# %%
data['last_price'].mean() # среднее значение по всему столбцу с ценами
# Out:
# 6553239.056723675

# %%
data[['last_price', 'total_area']].median() # медиана по цене и площадью квартиры
# Out:
# last_price    4650000.0
# total_area         52.0
# dtype: float64

# %%
data[['last_price', 'total_area']].describe()
# Out:
#          last_price    total_area
# count  2.344700e+04  23447.000000
# mean   6.553239e+06     60.435430
# std    1.092853e+07     35.693587
# min    1.219000e+04     12.000000
# 25%    3.450000e+06     40.000000
# 50%    4.650000e+06     52.000000
# 75%    6.800000e+06     70.000000
# max    7.630000e+08    900.000000

# %% [markdown]
# Метод describe по двум столбцам показывает значения, но нечитабельные по  столбцу last_price

# %%
data[['last_price', 'total_area']].describe().apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#          last_price total_area
# count      23447.00   23447.00
# mean     6553239.06      60.44
# std     10928532.42      35.69
# min        12190.00      12.00
# 25%      3450000.00      40.00
# 50%      4650000.00      52.00
# 75%      6800000.00      70.00
# max    763000000.00     900.00

# %% [markdown]
# Теперь видно минимальное и максимальное, среднее и медианое значение цеы объекта недвижимости в датасете, они кажутся неправдоподобными.
# Добавлю столбец **mean_price_aera** в дата сет для средней цены квадратного метра объекта недвижимости

# %%
# добавил в датасет столбец ценой за кв.м
data['mean_price_aera'] = round(data['last_price']/data['total_area']).astype(int)
data['mean_price_aera'].head()
# Out:
# 0    120370
# 1     82921
# 2     92786
# 3    408176
# 4    100000
# Name: mean_price_aera, dtype: int64

# %% [markdown]
# Добавим в дата сет столбцы с годом, месяцем и днем публикации объявления

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data['weekday_exposition'] = data['first_day_exposition'].dt.weekday
data['month_exposition'] = data['first_day_exposition'].dt.month
data['year_exposition'] = data['first_day_exposition'].dt.year

# %% [markdown]
# Добавим столбец со **floor_name** значением этажа квартиры: варианты — первый, последний, другой

# %%
data.loc[data['floor'] == 1, 'floor_name'] = 'первый'
data.loc[data['floor'] == data['floors_total'], 'floor_name'] = 'последний'
data.loc[data['floor_name'].isna(), 'floor_name'] = 'другой' # незаполненные значения меняем на 'другой'

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            2.65            14         45.0      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    ponds_nearest  days_exposition  locality_name_short  living_area_median  \
# ...

# %%
data['floor_name'].unique()
# Out:
# array(['другой', 'первый', 'последний'], dtype=object)

# %% [markdown]
# Найдем соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
data['living_area_part'] = round(data['living_area'] / data['total_area'], 2)
data['kitchen_area_part'] = round(data['kitchen_area'] / data['total_area'], 2)
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            2.65            14         45.0      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    locality_name_short  living_area_median  kitchen_area_median  \
# ...

# %% [markdown]
# ## Исследовательский анализ данных

# %%
data.describe().apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#       total_images    last_price total_area     rooms ceiling_height  \
# count     23447.00      23447.00   23447.00  23447.00       23447.00
# mean          9.88    6553239.06      60.44      2.08           2.70
# std           5.68   10928532.42      35.69      1.07           0.23
# min           0.00      12190.00      12.00      1.00           2.45
# 25%           6.00    3450000.00      40.00      1.00           2.60
# 50%           9.00    4650000.00      52.00      2.00           2.65
# 75%          14.00    6800000.00      70.00      3.00           2.70
# max          50.00  763000000.00     900.00     19.00           8.30
#
#       floors_total living_area     floor kitchen_area   balcony  ...  \
# count     23447.00    23447.00  23447.00     23447.00  23447.00  ...
# mean         10.69       34.39      5.88        10.47      0.59  ...
# std           6.59       21.75      4.87         5.63      0.96  ...
# ...

# %% [markdown]
# теперь видны минимальные и максимальные значения, а также стредние и медианные значения по всему датасету

# %% [markdown]
# ### Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.

# %%
# значение цены 3 квантиля 6,8 миллионов рублей, для посторения гистограммы возьму значения от 0 до 10 миллионов рублей. 
(data['last_price']/1000000).describe()
# Out:
# count    23447.000000
# mean         6.553239
# std         10.928532
# min          0.012190
# 25%          3.450000
# 50%          4.650000
# 75%          6.800000
# max        763.000000
# Name: last_price, dtype: float64

# %%
# Гистограмма по цене: основные обявления в районе  3,8 млн руб и 4,6 млн.руб

(data['last_price']/1000000).hist(bins=100, figsize=(10,5), range=(0, 10))
# Out:
# <AxesSubplot:>

# %%
data['total_area'].describe()
# Out:
# count    23447.000000
# mean        60.435430
# std         35.693587
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         70.000000
# max        900.000000
# Name: total_area, dtype: float64

# %%
# гистограмма по общей площади.
data['total_area'].hist(bins=200, figsize=(10,5), range=(0, 110))
# Out:
# <AxesSubplot:>

# %% [markdown]
# на гистограмме выделяется диапазон квартир с общей площадью от чуть более 30 до 60 с небольшим кв.м.
# судя по общей площади можно предположить, что это студии, однушки и двушки.
# Уточним это проанализировав объявления по количеству комнат

# %%
data['rooms'].describe()
# Out:
# count    23447.000000
# mean         2.080991
# std          1.067443
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
data['rooms'].hist(bins=200, figsize=(10,5), range=(-1,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# К предыдущему выводу, что большую часть объявлений составляют студии, однушки и двушки можно прибавить трехкомнатные квартиры.
# Квартир с 4 и более комнат уже значительно меньше

# %%
data['ceiling_height'].describe()
# Out:
# count    23447.000000
# mean         2.698790
# std          0.231623
# min          2.450000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          8.300000
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].hist(bins=300, figsize=(10,5), range=(2, 3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# В львиной доли объявлений высота составлет около 2,65 м - медианное значение по столбцу

# %% [markdown]
# ### Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
# посмотрим по дням размещения
data['days_exposition'].describe()
# Out:
# count    23447.000000
# mean       156.517806
# std        213.604232
# min          0.000000
# 25%         22.000000
# 50%         73.000000
# 75%        198.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Среднее значение дней  размещения объявления составляет 156 дней - 5 месяцев
#
# Медианное значение значительно меньше : 73 дня или 2,5 месяца.
# Большой разброс между средним и медианой связан с выбросами в данных

# %%
data['days_exposition'].hist(bins=300, figsize=(10,5), range=(1, 300))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Действительно имеются выбросы.
#
# На гистограмме видны импульсы до 100 дней размещения, перестрою гистограмму с этим учетом

# %%
data['days_exposition'].hist(bins=300, figsize=(10,5), range=(1, 100))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из этой гистограммы видны значения 7, 30, 45, 60 и 90 дней, по прошествии которых объявление закрывается.
#
# Импульс в 7 дней можно попробовать объяснить размещением объявления для проверки спроса на квартиру.
# Остальные импульсы в 30, 60 и 90 дней можно предположить, что закрытие объявления связано с тем, что объявление зачастую публикуется на 30 дней, после чего либо снимается с публикации, либо продлевается на следующие 30 дней, поэтому и видны импульсы в значениях, кратных 30.
#
# А вот выдающийся импульс в 45 дней в свете изложенного выше уже можно предположить то, что такие закрытия объявлений связано с выходом на реальную сделку. Единственно, что смущает, что это именно импульс, а не нормальное распределение значений.

# %% [markdown]
# ### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %% [markdown]
# Для получения средней длительности продажи буду брать данные без учета импульсов в значениях 30, 45, 60 и 90 дней.
#
# Предполагаю, что по умолчанию объявление публикуется на 30 дней, и когда подходит этот срок размещения - то действует оповещение пользователя о продлении объявления, либо включено автопродление объявления. Думаю, что по этим причинам наблюдаются импульсы в днях, кратных 30, и поэтому вероятнее всего такие закрытия объявления зачастую не связаны с продажей квартиры.
#
# 45 дней исключаю потому, что это именно импульс, который не даст посчитать корректное значение среднего времени продажи квартиры. Гистограмма не имеет вида Пуассона.
#
# Все импульсы заменю на медианное значение, чтобы посчитать среднее время размещения объявления.

# %%
days_exposition_median = data['days_exposition'].median()
days_exposition_median
# Out:
# 73.0

# %%
days_exposition_mean = data['days_exposition'].mean()
days_exposition_mean
# Out:
# 156.51780611592102

# %%
data['days_exposition'].describe()
# Out:
# count    23447.000000
# mean       156.517806
# std        213.604232
# min          0.000000
# 25%         22.000000
# 50%         73.000000
# 75%        198.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
# а если посчитать средний срок размещения объявления, исключив из расчета данные по 30, 45, 60 и 90 дням
data.loc[(data['days_exposition'] != 30) | (data['days_exposition'] != 45) | (data['days_exposition'] != 60) | (data['days_exposition'] != 90)]['days_exposition'].mean()
# Out:
# 156.51780611592102

# %% [markdown]
# одинаковое значение среднего срока размещения объявления

# %%
# Если посмотреть средний и медианный срок обявления в разрезе по количеству комнат
(
    data.query('days_exposition != 30 or days_exposition != 45 or days_exposition != 60 or days_exposition != 90')
        .pivot_table(index='rooms', values=['days_exposition'], aggfunc=('mean','median'))

)
# Out:
#       days_exposition
#                  mean  median
# rooms
# 1          142.771376    65.0
# 2          150.471794    72.0
# 3          169.075108    83.0
# 4          202.259829   101.5
# 5          237.206154   108.0
# 6          203.000000    93.0
# 7          124.135593    35.0
# 8          358.500000   241.5
# 9          231.750000    45.0
# 10          29.333333    11.0
# 11         406.500000   406.5
# 12         106.000000   106.0
# 14         256.500000   256.5
# 15          14.000000    14.0
# 16        1365.000000  1365.0
# 19         114.000000   114.0

# %%
# посмотрим информацию по столбцам с количеством комнат и общей площадью
# Судя по 3-ей квартили, объявлений с количеством комнат больше 3х - уже мало в датасете по сравнению с общим количеством объявлений
# Но посмотрим поточнее

data[['rooms','total_area']].describe()
# Out:
#               rooms    total_area
# count  23447.000000  23447.000000
# mean       2.080991     60.435430
# std        1.067443     35.693587
# min        1.000000     12.000000
# 25%        1.000000     40.000000
# 50%        2.000000     52.000000
# 75%        3.000000     70.000000
# max       19.000000    900.000000

# %% [markdown]
# Посмотрим сводной таблицей и  графиком число объявлений по количеству комнат

# %%
# Сводная таблица по количеству объявлений в зависимости от комнат
(
    data
    .pivot_table(index='rooms', values='total_area', aggfunc=('count','mean'))
#    .plot(y='count', kind='bar')
)
# Out:
#        count        mean
# rooms
# 1       8140   37.513517
# 2       7853   55.893066
# 3       5765   77.743599
# 4       1170  107.586795
# 5        325  161.517200
# 6        104  202.571635
# 7         59  265.325424
# 8         12  259.233333
# 9          8  305.975000
# 10         3  259.566667
# 11         2  188.900000
# 12         1  900.000000
# 14         2  304.200000
# 15         1  590.000000
# 16         1  270.000000
# 19         1  374.600000

# %%
# График для наглядности
(
    data
    .pivot_table(index='rooms', values='total_area', aggfunc=('count','mean'))
    .plot(kind='bar')
)
# Out:
# <AxesSubplot:xlabel='rooms'>

# %%
# редкие объявления с комнатами больше 7 в количестве 31 штуки
rare_flat = data.query('rooms > 7')
len(rare_flat)
# Out:
# 31

# %%
# посмотрим долю объявлений в датасете с числом комнат более 8 
(
    rare_flat
        .describe()
        .apply(lambda x: x.apply('{0:.2f}'.format))
)
# Out:
#       total_images    last_price total_area  rooms ceiling_height  \
# count        31.00         31.00      31.00  31.00          31.00
# mean          8.90   51752190.32     305.10  10.00           3.06
# std           5.55   78046320.66     140.50   2.80           0.39
# min           0.00   15500000.00     150.00   8.00           2.50
# 25%           5.00   19700000.00     232.50   8.00           2.65
# 50%           8.00   25000000.00     270.00   9.00           3.00
# 75%          13.00   38450000.00     347.25  10.50           3.33
# max          20.00  420000000.00     900.00  19.00           4.00
#
#       floors_total living_area  floor kitchen_area balcony  ... ponds_nearest  \
# count        31.00       31.00  31.00        31.00   31.00  ...         17.00
# mean          5.90      192.04   4.39        28.31    0.13  ...        389.06
# std           3.79       69.49   4.37        23.45    0.34  ...        236.17
# ...

# %%
len(data.query('rooms > 7'))/len(data)*100
# Out:
# 0.13221307629973986

# %% [markdown]
# Из графика видно, что количество объявлений падает с увеличением числа комнат, для анализа можно ограничиться объявлениями до 8 комнат.
#
# Доля таких объявлений составляет 0.13 процента от всего датасета - эти объявления редкие
#
# Так же из графика видно, что от количества комнат растет итоговая площадь
#
# Думаю для анализа оставить в датасете объявления с числом комнат до 8. Это поможет убрать также аномальные значения итоговой площади.

# %%
# удалили редкие объявления с комнатами более 7 штук
data = data.drop(rare_flat.index)

# %%
#Теперь доля редких квартир нулевая
len(data.query('rooms > 7'))/len(data)*100
# Out:
# 0.0

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %%
# Посмотрим корелляции

# %%
data_stat_corr = data.loc[:, ['total_area', 'last_price', 'rooms', 'city_centers_nearest']]
data_stat_corr.corr()
# Out:
#                       total_area  last_price     rooms  city_centers_nearest
# total_area              1.000000    0.642219  0.750273             -0.339799
# last_price              0.642219    1.000000  0.352802             -0.262721
# rooms                   0.750273    0.352802  1.000000             -0.294583
# city_centers_nearest   -0.339799   -0.262721 -0.294583              1.000000

# %% [markdown]
# Видно наличие корреляции общей площади и количества комнат, остальные параметры слабо коррелируют

# %%
pd.plotting.scatter_matrix(data_stat_corr, figsize=(15, 15))
# Out:
# array([[<AxesSubplot:xlabel='total_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='last_price', ylabel='total_area'>,
#         <AxesSubplot:xlabel='rooms', ylabel='total_area'>,
#         <AxesSubplot:xlabel='city_centers_nearest', ylabel='total_area'>],
#        [<AxesSubplot:xlabel='total_area', ylabel='last_price'>,
#         <AxesSubplot:xlabel='last_price', ylabel='last_price'>,
#         <AxesSubplot:xlabel='rooms', ylabel='last_price'>,
#         <AxesSubplot:xlabel='city_centers_nearest', ylabel='last_price'>],
#        [<AxesSubplot:xlabel='total_area', ylabel='rooms'>,
#         <AxesSubplot:xlabel='last_price', ylabel='rooms'>,
#         <AxesSubplot:xlabel='rooms', ylabel='rooms'>,
#         <AxesSubplot:xlabel='city_centers_nearest', ylabel='rooms'>],
#        [<AxesSubplot:xlabel='total_area', ylabel='city_centers_nearest'>,
#         <AxesSubplot:xlabel='last_price', ylabel='city_centers_nearest'>,
# ...

# %% [markdown]
# Из гистограмм видно:
# - Цена и общая площадь коррелируют
# - Чем больше комнат - тем больше общая площадь, что очевидно
# - большая часть объявлений находится на расстоянии 15 км от центра
# - большая часть объявлений квартир с числом комнат до 4
# - большинство объявлений по квартирам с большой площадью более 200 кв. м находится в пределах 10 км от центра

# %%
(
    data.pivot_table(index='floor_name', values='last_price', aggfunc='mean')
        .apply(lambda x: x.apply('{0:.2f}'.format))
)
# Out:
#             last_price
# floor_name
# другой      6659139.93
# первый      4769087.22
# последний   7116909.44

# %%
(
    data.pivot_table(index='floor_name', values='last_price', aggfunc='mean')
        .plot(y='last_price', style='o-')
#        .apply(lambda x: x.apply('{0:.2f}'.format))

)
# Out:
# <AxesSubplot:xlabel='floor_name'>

# %% [markdown]
# Первый этаж самый недорогой в объявлениях, зато последний этаж ценится больше всего

# %%
# зависимость цены от даты размещения: дня недели, месяца и года.

# %%
# зависимость цены от дня размещения:
(
    data.pivot_table(index='weekday_exposition', values='last_price')
        .sort_values(by='last_price', ascending=False)
        .apply(lambda x: x.apply('{0:.2f}'.format))
)
# Out:
#                     last_price
# weekday_exposition
# 5                   6951234.67
# 3                   6672045.58
# 0                   6521896.82
# 2                   6422943.60
# 4                   6367977.85
# 1                   6360596.71
# 6                   6249365.55

# %%
# зависимость цены от дня размещения:
(
    data.pivot_table(index='weekday_exposition', values='last_price')
#        .sort_values(by='last_price', ascending=False)
        .plot(y='last_price', style='o-')
)
# Out:
# <AxesSubplot:xlabel='weekday_exposition'>

# %% [markdown]
# Интересно получается, что в 5 и 3 день недели, а это суббота и четверг, размещаются самые дорогие обявления, зато в воскресенье и пятницу выставляются самые недорогие.
# Причем экстремумы приходятся именно на выходные: на субботу и воскресенье

# %%
# зависимость цены от месяца размещения:
(
    data.pivot_table(index='month_exposition', values='last_price')
        .sort_values(by='last_price', ascending=False)
        .apply(lambda x: x.apply('{0:.2f}'.format))
)
# Out:
#                   last_price
# month_exposition
# 9                 6802084.36
# 12                6751415.30
# 4                 6738957.11
# 7                 6613569.44
# 5                 6609036.47
# 1                 6532392.99
# 2                 6428469.35
# 11                6416373.76
# 8                 6367846.04
# 3                 6327884.72
# 6                 6292487.86
# 10                6177771.86

# %%
# зависимость цены от месяца размещения:
(
    data.pivot_table(index='month_exposition', values='last_price')
#        .sort_values(by='last_price', ascending=False)
#        .apply(lambda x: x.apply('{0:.2f}'.format))
        .plot(y='last_price', style='o-', grid=True, figsize=(12,6))
)
# Out:
# <AxesSubplot:xlabel='month_exposition'>

# %% [markdown]
# Согласно графику выгоднее всего продавать квартиру в декабре, а вот покупать лучше всего в октябре
# Посмотрим по году

# %%
# зависимость цены от года размещения:
(
    data.pivot_table(index='year_exposition', values='last_price')
        .sort_values(by='last_price', ascending=False)
        .apply(lambda x: x.apply('{0:.2f}'.format))
)
# Out:
#                   last_price
# year_exposition
# 2014             12046600.18
# 2015              8368056.94
# 2016              6817251.18
# 2019              6736715.43
# 2017              6503956.90
# 2018              5949592.30

# %%
# зависимость цены от месяца размещения:
(
    data.pivot_table(index='year_exposition', values='last_price')
        .plot(y='last_price', style='o-', grid=True, figsize=(12,6))
)
# Out:
# <AxesSubplot:xlabel='year_exposition'>

# %% [markdown]
# 2014 год - лучший год, чтобы продать квартиру.
# А вот покупать надо было в 2018 году.
# в 2014 году начались санкции из-за Крыма, курс доллар улетел, цены резко возрасли на все, так думаю, подорожание недвижимости  связано с санкциями.

# %% [markdown]
# в целом можно сделать вывод, что квартиру лучше всего продать в 2014 в декабре месяце в субботу или в крайнем случае в четверг.
# Идеальный момент для покупки - это 2018 год, октябрь, воскресенье.
# Эти объявления  - лучшие для сделки)

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %%
(
data['locality_name_short'].value_counts()
                           .head(10)
)
# Out:
# Санкт-Петербург    15559
# Мурино               581
# Кудрово              470
# Шушары               437
# Всеволожск           398
# Пушкин               366
# Колпино              337
# Парголово            327
# Гатчина              302
# Выборг               236
# Name: locality_name_short, dtype: int64

# %% [markdown]
# Лидер хит парада по количеству объявлений - Санкт-Петербург, что ожидаемо

# %%
# Сделаю индекс для дальнейшего поиска в нем
top_ten_index = (
data['locality_name_short'].value_counts()
                           .head(10)
).index
top_ten_index
# Out:
# Index(['Санкт-Петербург', 'Мурино', 'Кудрово', 'Шушары', 'Всеволожск',
#        'Пушкин', 'Колпино', 'Парголово', 'Гатчина', 'Выборг'],
#       dtype='object')

# %%
ten_locality_top = (data
                      .query('locality_name_short in @top_ten_index')
                      .pivot_table(index='locality_name_short', values='last_price', aggfunc='mean')
                      .sort_values('last_price', ascending=False)
                      .apply(lambda x: x.apply('{0:.2f}'.format))
                   )
ten_locality_top
# Out:
#                      last_price
# locality_name_short
# Санкт-Петербург      7990957.11
# Пушкин               6496432.42
# Парголово            4488074.80
# Кудрово              4354895.23
# Шушары               4113560.64
# Колпино              3866288.56
# Всеволожск           3789067.75
# Мурино               3688851.46
# Гатчина              3503044.24
# Выборг               3257978.81

# %% [markdown]
# Больше всего объявлений в Санкт-Петербруге, и самая большая средняя цена тоже там же.
# Зато Выборг имеет меньше всего объявлений, которые в среднем имеют самую маленькую стоимость

# %% [markdown]
# ###  Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %%
# расстояние до центра из метров в километры с округлением
data['city_centers_nearest_km'] = round(data['city_centers_nearest']/1000)

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            2.65            14         45.0      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    living_area_median  kitchen_area_median  mean_price_aera  \
# 0                51.0                 25.0           120370
# ...

# %%
(
data.query('locality_name_short == "Санкт-Петербург"')
    .pivot_table(index='city_centers_nearest_km', values='last_price')
#    .sort_values('last_price', ascending=False)
    .plot(y='last_price', style='o-', grid=True, figsize=(15,6))
)
# Out:
# <AxesSubplot:xlabel='city_centers_nearest_km'>

# %% [markdown]
# На графике наглядно видно уменьшение стоимости в зависимости от расстояния до центра.
#
# Можно сказать, что самые дорогие квартиры в радиусе 8 км от центра

# %% [markdown]
# ### Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?

# %%
data_centr_spb = data.query('city_centers_nearest_km < 7')
#data_centr_spb.reset_index()

# %%
# добавлю для удобства стлбец с ценой в млн
data_centr_spb.loc[:, 'price_mln'] = (data_centr_spb['last_price']/1000000)
data_centr_spb.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 24             8     6500000        97.2           2015-10-31      2
# 35             6    15500000       149.0           2017-06-26      5
# 61            18     7990000        74.0           2017-08-24      2
# 63             2    20000000       118.0           2018-09-11      3
# 99            32     9600000        90.0           2017-09-26      4
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 24            2.65             3         46.5      1         False  ...
# 35            2.65             5        104.0      4         False  ...
# 61            2.65             4         43.0      4         False  ...
# 63            3.00             9         68.0      7         False  ...
# 99            2.65             5         67.0      2         False  ...
#
#     kitchen_area_median  mean_price_aera  weekday_exposition  \
# ...

# %%
data_centr_spb[['total_area', 'price_mln', 'rooms', 'ceiling_height', 'days_exposition', 'city_centers_nearest_km']].describe().apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#       total_area price_mln    rooms ceiling_height days_exposition  \
# count    3062.00   3062.00  3062.00        3062.00         3062.00
# mean       93.63     14.74     2.85           2.96          211.13
# std        58.16     24.88     1.34           0.38          271.30
# min        12.00      1.60     1.00           2.45            0.00
# 25%        58.80      6.80     2.00           2.65           22.00
# 50%        80.00      9.30     3.00           2.84           98.00
# 75%       110.00     14.00     4.00           3.20          298.75
# max       631.20    763.00     7.00           6.00         1572.00
#
#       city_centers_nearest_km
# count                 3062.00
# mean                     4.16
# std                      1.51
# min                      0.00
# 25%                      3.00
# 50%                      4.00
# 75%                      5.00
# max                      6.00

# %% [markdown]
# В центре имеем 3083 объявления:
#
# В среднем получается, что в центре больше всего объявлений о 3х комнатных квартирах, с высотой потолка 3 метра, площадью 95 кв.м. Такая квартира продается за 212 дней, стоимость 15 миллионов рублей.
#
# Если же смотреть по медиане, то получается тоже трешка, площадью 80 кв.м, потолки 2.85, цена 9,4 млн руб, срок объявления 98 дней.
#
# Посмотрим гистограммой

# %%
data_centr_spb['total_area'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большая часть объявлений до 100 кв.м

# %%
data_centr_spb.boxplot('total_area')
plt.ylim(0,200)
plt.title('Площадь квартир')
plt.xlabel('Общая площадь, кв. м')
plt.show()

# %%
# Средняя цена квартиры
data_centr_spb['price_mln'].mean().round()
# Out:
# 15.0

# %%
data_centr_spb['price_mln'].hist(bins=200, range=(0, 20))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Больше всего объявлений с ценой в 7,5 млн руб.

# %%
data_centr_spb.boxplot('price_mln')
plt.ylim(0,30)
plt.title('Цена квартир')
plt.xlabel('цена, млн. руб')
plt.show()

# %%
# Если посмотреть сводную таблицу по километрам, то видно из нее, что доминируют объявления трехкомнатных квартир,
# И средняя, медианная цена при удалении от центра уменьшатся
data_centr_spb.pivot_table(index='city_centers_nearest_km', values=['rooms','total_area','price_mln'], aggfunc=['count','mean','median'])
# Out:
#                             count                        mean            \
#                         price_mln rooms total_area  price_mln     rooms
# city_centers_nearest_km
# 0.0                            27    27         27  31.449116  3.074074
# 1.0                           190   190        190  21.139476  3.205263
# 2.0                           305   305        305  17.733181  3.072131
# 3.0                           345   345        345  10.913372  2.962319
# 4.0                           681   681        681  13.049304  2.917768
# 5.0                           902   902        902  14.386083  2.786031
# 6.0                           612   612        612  15.088321  2.571895
#
#                                        median
#                          total_area price_mln rooms total_area
# city_centers_nearest_km
# 0.0                      117.259259    17.900     3     100.00
# 1.0                      104.077263    11.275     3      86.25
# ...

# %%
# хоть 3х комнатные квартиры - лидер по объявлениям, но двухкомнатные не отстают., значительно меньше остальных квартир
data_centr_spb['rooms'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
#Шикарная высота потолка в 3 метра
data_centr_spb['ceiling_height'].mean().round()
# Out:
# 3.0

# %%
data_centr_spb['ceiling_height'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
# Среднее время продажи квартиры в центре 212 дней, медианное 98 дней
data_centr_spb['days_exposition'].describe()
# Out:
# count    3062.000000
# mean      211.126388
# std       271.299709
# min         0.000000
# 25%        22.000000
# 50%        98.000000
# 75%       298.750000
# max      1572.000000
# Name: days_exposition, dtype: float64

# %%
#Рассчитаем матрицу корреляция в столбах которые влияют на стоимость квартиры
data_centr_spb_corr = data_centr_spb[['price_mln','ceiling_height','rooms','total_area','floor','days_exposition']]
data_centr_spb_corr.corr()
# Out:
#                  price_mln  ceiling_height     rooms  total_area     floor  \
# price_mln         1.000000        0.134500  0.305102    0.607634  0.122301
# ceiling_height    0.134500        1.000000  0.228278    0.252856 -0.129768
# rooms             0.305102        0.228278  1.000000    0.728248 -0.027571
# total_area        0.607634        0.252856  0.728248    1.000000  0.122314
# floor             0.122301       -0.129768 -0.027571    0.122314  1.000000
# days_exposition   0.023333        0.018574  0.063184    0.067633  0.037712
#
#                  days_exposition
# price_mln               0.023333
# ceiling_height          0.018574
# rooms                   0.063184
# total_area              0.067633
# floor                   0.037712
# days_exposition         1.000000

# %% [markdown]
# Самый большой коэфф корелляции между уеной и площадью квартиры, что в целом очевидно - чем больше площадь, тем больше стоимость

# %%
pd.plotting.scatter_matrix(data_centr_spb_corr, figsize=(16,16))
# Out:
# array([[<AxesSubplot:xlabel='price_mln', ylabel='price_mln'>,
#         <AxesSubplot:xlabel='ceiling_height', ylabel='price_mln'>,
#         <AxesSubplot:xlabel='rooms', ylabel='price_mln'>,
#         <AxesSubplot:xlabel='total_area', ylabel='price_mln'>,
#         <AxesSubplot:xlabel='floor', ylabel='price_mln'>,
#         <AxesSubplot:xlabel='days_exposition', ylabel='price_mln'>],
#        [<AxesSubplot:xlabel='price_mln', ylabel='ceiling_height'>,
#         <AxesSubplot:xlabel='ceiling_height', ylabel='ceiling_height'>,
#         <AxesSubplot:xlabel='rooms', ylabel='ceiling_height'>,
#         <AxesSubplot:xlabel='total_area', ylabel='ceiling_height'>,
#         <AxesSubplot:xlabel='floor', ylabel='ceiling_height'>,
#         <AxesSubplot:xlabel='days_exposition', ylabel='ceiling_height'>],
#        [<AxesSubplot:xlabel='price_mln', ylabel='rooms'>,
#         <AxesSubplot:xlabel='ceiling_height', ylabel='rooms'>,
#         <AxesSubplot:xlabel='rooms', ylabel='rooms'>,
# ...

# %%
data_centr_spb[['total_area', 'price_mln', 'rooms', 'ceiling_height', 'days_exposition', 'city_centers_nearest_km']].describe().apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#       total_area price_mln    rooms ceiling_height days_exposition  \
# count    3062.00   3062.00  3062.00        3062.00         3062.00
# mean       93.63     14.74     2.85           2.96          211.13
# std        58.16     24.88     1.34           0.38          271.30
# min        12.00      1.60     1.00           2.45            0.00
# 25%        58.80      6.80     2.00           2.65           22.00
# 50%        80.00      9.30     3.00           2.84           98.00
# 75%       110.00     14.00     4.00           3.20          298.75
# max       631.20    763.00     7.00           6.00         1572.00
#
#       city_centers_nearest_km
# count                 3062.00
# mean                     4.16
# std                      1.51
# min                      0.00
# 25%                      3.00
# 50%                      4.00
# 75%                      5.00
# max                      6.00

# %%
data[['total_area', 'last_price', 'rooms', 'ceiling_height', 'days_exposition', 'city_centers_nearest']].describe().apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#       total_area    last_price     rooms ceiling_height days_exposition  \
# count   23416.00      23416.00  23416.00       23416.00        23416.00
# mean       60.11    6493401.02      2.07           2.70          156.33
# std        34.22   10444058.86      1.02           0.23          213.29
# min        12.00      12190.00      1.00           2.45            0.00
# 25%        40.00    3443000.00      1.00           2.60           22.00
# 50%        52.00    4650000.00      2.00           2.65           73.00
# 75%        69.70    6790000.00      3.00           2.70          198.00
# max       631.20  763000000.00      7.00           8.30         1580.00
#
#       city_centers_nearest
# count             15559.00
# mean              11607.83
# std                4820.83
# min                 181.00
# 25%                8370.00
# 50%               12262.00
# 75%               14938.00
# max               29493.00

# %% [markdown]
# Если сравнивать продажы в центре и продажи по всему датасету, то можно сказать, что в центре больше всего продается трехкомнатных квартир, срок продажи 98 дней, долгая продажа - 200 и более дней. Стоимость трешки 9.4 млн.руб, площадь 80 кв.м, в радиусе 4х км от центра, потолки  2.85 метра.
#
# Что касается всех объявлений, то лидируют двухкомнатные квартиры, срок продажи 73 дня, долгая продажа - 156 дней. Стоимость двухкомнатной квартиры 4,65 млн.руб, площадь 52 кв.м., в радиусе 12 км от центра, потолки 2.7 метра.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# ### Факторы влияющие на цену квартир.
# - Больше половины квартир продается по цене до 5 млн. рублей.
# - На цену м² существенное влияние оказывает общая площадь квартиры, в квартирах в центе  корреляция составляет 0.6, в квартирах по всему датасету составляет 0.65
# - Этаж тоже оказывает влияние на стоимость квартиры. Самые дешевые квартиры на первом этаже, а квартиры на последнем этаже - самые дорогие
# - Удаленность квартиры от центра влияет на ее стоимость существенно, это один из основных факторов, влияющих на стоимость, Зависимость цены от удаленности - обратно пропорциональная , чем дальше - тем дешевле квартира.
# - Лучшее время для продажи квартиры - это декабрь, воскресенье - объявления в этот период самые дорогие. Для покупки лучше рассмотреть объявления, созданные в октябре  в субботу.
#
# ### Параметры квартир, лучше всего продающихся в центе Санкт-Петербурга:
# - В основном продаются квартиры площадью 80 м².
# - Типичная цена продажи 9,4 млн. рублей.
# - Комнаты 3.
# - Высота потолков 2,85 м.
# - Время продажи составляет 98 дней. Долгая продажа 200 дней.
#
# ### Параметры квартир, лучше всего продающихся по Санкт-Петербугру:
# - В основном продаются квартиры площадью 40 - 70 м².
# - Типичная цена продажи 3.45 - 6.8 млн. рублей.
# - Комнаты от 1 до 3.
# - Высота потолков 2.6 - 2.7 м.
# - Время продажи составляет 78 дней. Долгая продажа 156 дней

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
